# %%
import pandas as pd
import sqlite3 as sql
import nltk

# %%
conn = sql.connect("track_metadata.db")
# conn2 = sql.connect("dat/mxm_dataset.db")
c = conn.cursor()

# %%
for row in c.execute("SELECT name FROM main.sqlite_master WHERE type='table';"):
    print(row)
# Out:
# ('songs',)

# %%
c.execute("attach 'mxm_dataset.db' AS lyr;")
c.execute("attach 'lastfm_tags.db' AS tag;")

# %%
for row in c.execute("SELECT name FROM lyr.sqlite_master WHERE type='table';"):
    print(row)
# Out:
# ('words',)
# ('lyrics',)

# %%
for row in c.execute("SELECT name FROM tag.sqlite_master WHERE type='table';"):
    print(row)
# Out:
# ('tags',)
# ('tids',)
# ('tid_tag',)

# %%
q = '''
SELECT * FROM songs
LIMIT 200;
'''

# %%
q2 = '''
SELECT * FROM lyrics
LIMIT 200;
'''

# %%
c1 = '''
ATTACH DATABASE "dat/mxm_dataset.db" AS conn3;
'''

# %%
c2 = '''
ATTACH DATABASE "dat/artist_term.db" AS conn3;
'''

# %%
songs = pd.read_sql("SELECT * FROM main.songs", conn)
lyrics = pd.read_sql("SELECT * FROM lyr.lyrics LIMIT 100", conn)
genres = pd.read_sql("SELECT * FROM tag.tags LIMIT 100", conn)
gtags = pd.read_sql("SELECT * FROM tag.tid_tag LIMIT 100", conn)

# %% [markdown]
# # Cleaning Begins!

# %%
#artist name, song title, release, all lowercase
songs["title"] = songs["title"].str.lower()
songs["release"] = songs["release"].str.lower()
songs["artist_name"] = songs["artist_name"].str.lower()

#drops artist hotttness metric; drops na vals
songs = songs.drop(columns = ["artist_hotttnesss", "track_7digitalid", "shs_perf", "shs_work", "artist_mbid"])
songs = songs.dropna()

# %%
#trim songs with years before 1975
songs = songs[songs.year > 1975]

#renaming the title column to "song_name" and rename "release" to "album_name"
songs = songs.rename(columns={"title":"song_name", "release":"album_name"})

# %%
#dropping based on familiarity being below 20
songs = songs[songs.artist_familiarity > .2]
songs = songs.sort_values(by = "artist_familiarity", ascending = False)

#removes rows with blank song entries
songs = songs[songs.song_name.str.len() > 1].sort_values(by="song_name")

#removes rows with years before 1975
songs = songs[songs.year > 1975]

print(len(songs))
# Out:
# 482823

# %%
#duplicate removal--removes all duplicate songs by matching artist id

################## Note: this step removes duplicates when song_name and artist_id are exactly the same
################## but not different versions of a same song

songs = songs.sort_values(by = "artist_name")
songs["s/a"] = songs["song_name"]+songs["artist_id"] #song-artist concatenation column
songs = songs.drop_duplicates("s/a", keep = 'first')
print(len(songs))
# Out:
# 438616

# %%
#######check############
print(list(songs.columns.values))
print(min(songs['year']),max(songs['year']))
# Out:
# ['track_id', 'song_name', 'song_id', 'album_name', 'artist_id', 'artist_name', 'duration', 'artist_familiarity', 'year', 's/a']
# 1976 2011

# %% [markdown]
#  # TODO: if alternate versions of songs exist, keep the original only

# %%
import re
pattern = r' \(.*?version\)'

# %%
dump = re.search(pattern, '(bad version) (better version)')

# %%
dump.span(0)
# Out:
# (13, 30)

# %%
dump = songs['song_name'].map(lambda s: len(list(re.finditer(pattern, s))))

# %%
import numpy as np
dump = np.asarray(dump)
print((dump <= 1).sum())
print(len(dump))
# Out:
# 438582
# 438616

# %%
#IMPLIMENT IRENE!
#test: see how different versions are represented
#first, try to find some examples
#songs.groupby('artist_id').count().sort_values(by='song_name', ascending=False)
#checkout the artist with the most entry
#songs.loc[songs['song_name'].str.contains('version')].sort_values(by='song_name', ascending=False)
#drop all the (xx version) part of the song name and see if the remaining string still has duplicates
def clean_string(s):
    match_obj = re.search(pattern, s)
    if match_obj is None:
        return s
    start, end = match_obj.span(0)
    return s[:start] + s[end:]

songs['song_name_cleaned'] = songs['song_name'].map(clean_string)

# %%
print(len(songs))
songs['s_cleaned/a'] = songs["song_name_cleaned"]+songs["artist_id"]
songs_test = songs.sort_values(by='s_cleaned/a')
songs_test = songs.drop_duplicates("s_cleaned/a", keep = 'first')
print(len(songs_test))
# Out:
# 438616
# 436690

# %%
#so there are duplicates! Even after dropping the "version" part! But not that many!
#for now I am going to just keep the OLDEST of uplicates, regardless of which version it is
#do we need to keep specific version? say, favor EP version to album version?
songs = songs.sort_values(['s_cleaned/a', 'year'])
songs = songs.drop_duplicates("s_cleaned/a", keep = 'first')
print(len(songs))
# Out:
# 436690

# %%
songs.head(10)
# Out:
#                   track_id                                          song_name  \
# 548988  TRTBNCR128F424378D                                 till kingdom come
# 129025  TRHZQPU128F4248D91
# ef ég hefði aldrei...
# 290346  TRFTRGQ128F4248D70
# eg sleppi þer aldrei
# 584850  TRUCXGV128F422BB0D
# the arsonist story":  evil craves attention/o...
# 343266  TRQXVIR128F422BB0B
# the arsonist story":  evil plays piano
# 530024  TRPSEYQ128F422BB12
# the arsonist story":  trapped and drowning
# 972174  TRYFMAC128F422BB08
# the arsonist story": fireman
# 138487  TRHUSPZ128EF35F572
# why im a lawbreaker
# 963984  TRYWPZY128F4248D80
# ég heyrði allt án þess að hlusta
# 517592  TRPAQJI128F4248D8D
# ég átti gráa æsku
#
#                    song_id                album_name           artist_id  \
# 548988  SORLDBM12A8C1335D6                old growth  ARNEMNT1187B9B44B1
# 129025  SOKBHBV12A8C130430                 englabörn  ARXO7AU1187B9B249F
# 290346  SOVHCGB12A8C1303EA                 englabörn  ARXO7AU1187B9B249F
# 584850  SOQOVFQ12A6D4FAE4B                      1212  AR9HLNV1187B98EFC6
# 343266  SOTRINY12A6D4FAE46                      1212  AR9HLNV1187B98EFC6
# 530024  SOUZGEF12A6D4FAE62                      1212  AR9HLNV1187B98EFC6
# 972174  SORQBMP12A6D4FAE43                      1212  AR9HLNV1187B98EFC6
# 138487  SOYBKQK12A6D4F66CA  weaponry listens to love  AR20Z421187FB40C07
# 963984  SORXLSH12A8C13040A                 englabörn  ARXO7AU1187B9B249F
# 517592  SOUDIUF12A8C130429                 englabörn  ARXO7AU1187B9B249F
#
#               artist_name   duration  artist_familiarity  year  \
# 548988        dead meadow  245.99465            0.690974  2008
# 129025  johann johannsson  222.87628            0.625280  2002
# 290346  johann johannsson  177.94567            0.625280  2002
# 584850    barbara manning  485.61587            0.491941  1997
# 343266    barbara manning   41.24689            0.491941  1997
# 530024    barbara manning  420.75383            0.491941  1997
# 972174    barbara manning  177.05751            0.491941  1997
# 138487         huggy bear   84.66240            0.552386  1994
# 963984  johann johannsson  125.04771            0.625280  2002
# 517592  johann johannsson  221.28281            0.625280  2002
#
#                                                       s/a  \
# 548988               till kingdom comeARNEMNT1187B9B44B1
# 129025
# ef ég hefði aldrei...ARXO7AU1187B9B249F
# 290346
# eg sleppi þer aldreiARXO7AU1187B9B249F
# 584850
# the arsonist story":  evil craves attention/o...
# 343266
# the arsonist story":  evil plays pianoAR9HLNV...
# 530024
# the arsonist story":  trapped and drowningAR9...
# 972174
# the arsonist story": firemanAR9HLNV1187B98EFC6
# 138487
# why im a lawbreakerAR20Z421187FB40C07
# 963984
# ég heyrði allt án þess að hlustaARXO7AU1187B9...
# 517592
# ég átti gráa æskuARXO7AU1187B9B249F
#
#                                         song_name_cleaned  \
# 548988                                 till kingdom come
# 129025
# ef ég hefði aldrei...
# 290346
# eg sleppi þer aldrei
# 584850
# the arsonist story":  evil craves attention/o...
# 343266
# the arsonist story":  evil plays piano
# 530024
# the arsonist story":  trapped and drowning
# 972174
# the arsonist story": fireman
# 138487
# why im a lawbreaker
# 963984
# ég heyrði allt án þess að hlusta
# 517592
# ég átti gráa æsku
#
#                                               s_cleaned/a
# 548988               till kingdom comeARNEMNT1187B9B44B1
# 129025
# ef ég hefði aldrei...ARXO7AU1187B9B249F
# 290346
# eg sleppi þer aldreiARXO7AU1187B9B249F
# 584850
# the arsonist story":  evil craves attention/o...
# 343266
# the arsonist story":  evil plays pianoAR9HLNV...
# 530024
# the arsonist story":  trapped and drowningAR9...
# 972174
# the arsonist story": firemanAR9HLNV1187B98EFC6
# 138487
# why im a lawbreakerAR20Z421187FB40C07
# 963984
# ég heyrði allt án þess að hlustaARXO7AU1187B9...
# 517592
# ég átti gráa æskuARXO7AU1187B9B249F

# %% [markdown]
# # Begin Merging Genre and Lyrics Section

# %%
#this section is to determine the most popular genre labels

"""sg = pd.read_sql("SELECT tag.tids.tid, tag.tags.tag FROM tag.tid_tag \
            INNER JOIN tag.tags ON tag.tags.ROWID==tag.tid_tag.tag \
            INNER JOIN tag.tids ON tag.tid_tag.tid==tag.tids.ROWID \
             LIMIT 1000000", conn)"""

sg = pd.read_sql("SELECT tag.tids.tid, tag.tags.tag FROM tag.tid_tag \
            INNER JOIN tag.tags ON tag.tags.ROWID==tag.tid_tag.tag \
            INNER JOIN tag.tids ON tag.tid_tag.tid==tag.tids.ROWID \
             ", conn)

data = pd.DataFrame()
sg['tag'] = sg.tag.str.lower()
gdict = sg['tag'].value_counts().to_dict()
populargenres = pd.DataFrame.from_dict(gdict, orient='index', columns = ['genre_count'])

# %%
populargenres.columns=['genre','genre_count']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-d810fd5502ef> in <module>()
# ----> 1 populargenres.columns=[['genre','genre_count']]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements

# %%
holdgenre = populargenres.index.get_values()
populargenres["genre"] = holdgenre

# %%
sg_frequency=sg.merge(populargenres,left_on='tag',right_on='genre',how='left')

# %%
sg_frequency.head()
# Out:
#                   tid               tag  genre_count             genre
# 0  TRCCCYE12903CFF0E9      classic rock        25771      classic rock
# 1  TRCCCYE12903CFF0E9  progressive rock        13406  progressive rock
# 2  TRCCCFH12903CEBC70             blues        20474             blues
# 3  TRCCCFH12903CEBC70      memphis slim           19      memphis slim
# 4  TRCCCJT128F429FFF6               pop        69159               pop

# %%
df_songs_merge=songs.merge(sg_frequency,left_on='track_id',right_on='tid',how='left')

# %%
df_songs_merge=df_songs_merge[~df_songs_merge['tag'].isna()]

# %%
df_songs_merge
# Out:
#                    track_id  \
# 13       TRPMYJW128F9323194
# 14       TRPMYJW128F9323194
# 15       TRPMYJW128F9323194
# 16       TRPMYJW128F9323194
# 17       TRPMYJW128F9323194
# 18       TRHAEMQ128F427C025
# 19       TRHAEMQ128F427C025
# 20       TRHAEMQ128F427C025
# 23       TRJCBRC128F92D0FBC
# 24       TRWJHXP128F92D0FA2
# 25       TRWJHXP128F92D0FA2
# 26       TRWJHXP128F92D0FA2
# 27       TRWJHXP128F92D0FA2
# 28       TRWJHXP128F92D0FA2
# 29       TRWJHXP128F92D0FA2
# 30       TRWJHXP128F92D0FA2
# 31       TRWJHXP128F92D0FA2
# 34       TRNRBRP128F92D0FA0
# 35       TRFUYKH128F92D0F94
# 38       TRNFYYX128F92D0F97
# 41       TRPLTPU128F92D0F99
# 42       TRPLTPU128F92D0F99
# 43       TRPLTPU128F92D0F99
# 44       TRPLTPU128F92D0F99
# 46       TRBKUIX12903CEB628
# 47       TRBKUIX12903CEB628
# 48       TRBKUIX12903CEB628
# 49       TRKSBXN12903CEB625
# 50       TRKSBXN12903CEB625
# 51       TRKSBXN12903CEB625
# ...                     ...
# 5296147  TRKENBJ128F425B50C
# 5296148  TRKENBJ128F425B50C
# 5296150  TROBLSX128F9306CDA
# 5296151  TROBLSX128F9306CDA
# 5296152  TROBLSX128F9306CDA
# 5296153  TROBLSX128F9306CDA
# 5296154  TROBLSX128F9306CDA
# 5296156  TRRYWAP128F9306CD7
# 5296158  TRMNPZP128F933881E
# 5296160  TRUUNSO128F42AADDC
# 5296161  TRUUNSO128F42AADDC
# 5296162  TRUUNSO128F42AADDC
# 5296163  TRUUNSO128F42AADDC
# 5296164  TRUUNSO128F42AADDC
# 5296165  TRUUNSO128F42AADDC
# 5296166  TRUUNSO128F42AADDC
# 5296167  TRUUNSO128F42AADDC
# 5296168  TRUUNSO128F42AADDC
# 5296169  TRUUNSO128F42AADDC
# 5296170  TRGLVCV128F425B50D
# 5296171  TRGLVCV128F425B50D
# 5296172  TRGLVCV128F425B50D
# 5296173  TRGLVCV128F425B50D
# 5296174  TRGLVCV128F425B50D
# 5296175  TRGLVCV128F425B50D
# 5296176  TRGLVCV128F425B50D
# 5296177  TRGLVCV128F425B50D
# 5296178  TRGLVCV128F425B50D
# 5296179  TRGLVCV128F425B50D
# 5296182  TRNNGEP128F425B4B5
#
#                                                  song_name  \
# 13                                                  camera
# 14                                                  camera
# 15                                                  camera
# 16                                                  camera
# 17                                                  camera
# 18                                                    ayso
# 19                                                    ayso
# 20                                                    ayso
# 23                                        todas las noches
# 24                              creeping thru lower levels
# 25                              creeping thru lower levels
# 26                              creeping thru lower levels
# 27                              creeping thru lower levels
# 28                              creeping thru lower levels
# 29                              creeping thru lower levels
# 30                              creeping thru lower levels
# 31                              creeping thru lower levels
# 34                                                raise up
# 35                                                  no luv
# 38                                                  aedena
# 41                                           drexion caves
# 42                                           drexion caves
# 43                                           drexion caves
# 44                                           drexion caves
# 46       opaque: the morning i woke up dead: today is t...
# 47       opaque: the morning i woke up dead: today is t...
# 48       opaque: the morning i woke up dead: today is t...
# 49         angelina: chthonian earth: her face forms worms
# 50         angelina: chthonian earth: her face forms worms
# 51         angelina: chthonian earth: her face forms worms
# ...                                                    ...
# 5296147                                               life
# 5296148                                               life
# 5296150                                           airwaves
# 5296151                                           airwaves
# 5296152                                           airwaves
# 5296153                                           airwaves
# 5296154                                           airwaves
# 5296156                               dream within a dream
# 5296158                                      touch my soul
# 5296160                                                two
# 5296161                                                two
# 5296162                                                two
# 5296163                                                two
# 5296164                                                two
# 5296165                                                two
# 5296166                                                two
# 5296167                                                two
# 5296168                                                two
# 5296169                                                two
# 5296170                                           pictures
# 5296171                                           pictures
# 5296172                                           pictures
# 5296173                                           pictures
# 5296174                                           pictures
# 5296175                                           pictures
# 5296176                                           pictures
# 5296177                                           pictures
# 5296178                                           pictures
# 5296179                                           pictures
# 5296182                                            scanner
#
#                     song_id                                   album_name  \
# 13       SOCKIWT12AB017F1A6                      a house full of friends
# 14       SOCKIWT12AB017F1A6                      a house full of friends
# 15       SOCKIWT12AB017F1A6                      a house full of friends
# 16       SOCKIWT12AB017F1A6                      a house full of friends
# 17       SOCKIWT12AB017F1A6                      a house full of friends
# 18       SOOWKJU12A58A7A6F2  sevensummers - international pop volume two
# 19       SOOWKJU12A58A7A6F2  sevensummers - international pop volume two
# 20       SOOWKJU12A58A7A6F2  sevensummers - international pop volume two
# 23       SOKQBUR12A8C143F52                                   day by day
# 24       SOHULMD12A8C140603                           ain't-chit history
# 25       SOHULMD12A8C140603                           ain't-chit history
# 26       SOHULMD12A8C140603                           ain't-chit history
# 27       SOHULMD12A8C140603                           ain't-chit history
# 28       SOHULMD12A8C140603                           ain't-chit history
# 29       SOHULMD12A8C140603                           ain't-chit history
# 30       SOHULMD12A8C140603                           ain't-chit history
# 31       SOHULMD12A8C140603                           ain't-chit history
# 34       SOVQFSO12A8C1405F6                           ain't-chit history
# 35       SOQWDMH12A8C142B57                           ain't-chit history
# 38       SOGQRSI12A8C142B76                           ain't-chit history
# 41       SOQBILM12A8C142B88                           ain't-chit history
# 42       SOQBILM12A8C142B88                           ain't-chit history
# 43       SOQBILM12A8C142B88                           ain't-chit history
# 44       SOQBILM12A8C142B88                           ain't-chit history
# 46       SOQUFJB12A67ADE8D0                                       cypher
# 47       SOQUFJB12A67ADE8D0                                       cypher
# 48       SOQUFJB12A67ADE8D0                                       cypher
# 5296179  2002                         picturesARKCA8N1187B9AE31A
# 5296182  2002                          scannerARKCA8N1187B9AE31A
#
#                         tid  \
# 13       TRPMYJW128F9323194
# 14       TRPMYJW128F9323194
# 15       TRPMYJW128F9323194
# 16       TRPMYJW128F9323194
# 17       TRPMYJW128F9323194
# 18       TRHAEMQ128F427C025
# 19       TRHAEMQ128F427C025
# 20       TRHAEMQ128F427C025
# 23       TRJCBRC128F92D0FBC
# 24       TRWJHXP128F92D0FA2
# 25       TRWJHXP128F92D0FA2
# 26       TRWJHXP128F92D0FA2
# 27       TRWJHXP128F92D0FA2
# 28       TRWJHXP128F92D0FA2
# 29       TRWJHXP128F92D0FA2
# 30       TRWJHXP128F92D0FA2
# 31       TRWJHXP128F92D0FA2
# 34       TRNRBRP128F92D0FA0
# 35       TRFUYKH128F92D0F94
# 38       TRNFYYX128F92D0F97
# 41       TRPLTPU128F92D0F99
# 42       TRPLTPU128F92D0F99
# 43       TRPLTPU128F92D0F99
# 44       TRPLTPU128F92D0F99
# 46       TRBKUIX12903CEB628
# 47       TRBKUIX12903CEB628
# 48       TRBKUIX12903CEB628
# 49       TRKSBXN12903CEB625
# 50       TRKSBXN12903CEB625
# 51       TRKSBXN12903CEB625
# ...                     ...
# 5296147  TRKENBJ128F425B50C
# 5296148  TRKENBJ128F425B50C
# 5296150  TROBLSX128F9306CDA
# 5296151  TROBLSX128F9306CDA
# 5296152  TROBLSX128F9306CDA
# 5296153  TROBLSX128F9306CDA
# 5296154  TROBLSX128F9306CDA
# 5296156  TRRYWAP128F9306CD7
# 5296158  TRMNPZP128F933881E
# 5296160  TRUUNSO128F42AADDC
# 5296161  TRUUNSO128F42AADDC
# 5296162  TRUUNSO128F42AADDC
# 5296163  TRUUNSO128F42AADDC
# 5296164  TRUUNSO128F42AADDC
# 5296165  TRUUNSO128F42AADDC
# 5296166  TRUUNSO128F42AADDC
# 5296167  TRUUNSO128F42AADDC
# 5296168  TRUUNSO128F42AADDC
# 5296169  TRUUNSO128F42AADDC
# 5296170  TRGLVCV128F425B50D
# 5296171  TRGLVCV128F425B50D
# 5296172  TRGLVCV128F425B50D
# 5296173  TRGLVCV128F425B50D
# 5296174  TRGLVCV128F425B50D
# 5296175  TRGLVCV128F425B50D
# 5296176  TRGLVCV128F425B50D
# 5296177  TRGLVCV128F425B50D
# 5296178  TRGLVCV128F425B50D
# 5296179  TRGLVCV128F425B50D
# 5296182  TRNNGEP128F425B4B5
#
#                                                        tag  genre_count  \
# 13                                            great covers        443.0
# 14                                        for my dancy mix          3.0
# 15                                             stereo cool         65.0
# 16                                     dream for me please          5.0
# 17       thissongmakesmewanttocrynotafraidtosharemyemot...          1.0
# 18                                                   happy      12291.0
# 19                                                       -         53.0
# 20                                        the office girls         98.0
# 23                                             future funk         39.0
# 24                                                     808         83.0
# 25                                       electglitchdubhop        682.0
# 26                                         minimal electro        292.0
# 27                                       electlgitchdubhop         57.0
# 28                                              electronic      46270.0
# 29                                                 electro      14041.0
# 30                                             electrofunk        305.0
# 31                                                 machine         45.0
# 34                                                 electro      14041.0
# 35                                   mac progressive house          1.0
# 38                         orange label ambient electronic        123.0
# 41                                                   house      12404.0
# 42                                                  techno      10679.0
# 43                                                   dutch       1515.0
# 44                                                  delsin          7.0
# 46                                             black metal       4694.0
# 47                                        industrial metal       2441.0
# 48                                extreme industrial metal          4.0
# 49                                  industrial black metal        160.0
# 50                                             black metal       4694.0
# 51                                                 finnish       3958.0
# ...                                                    ...          ...
# 5296147                                            electro      14041.0
# 5296148                                               warm       1190.0
# 5296150                                            ambient      17982.0
# 5296151                                                dub       4383.0
# 5296152                                         electronic      46270.0
# 5296153                                        electronica      24087.0
# 5296154                                          downtempo      11466.0
# 5296156                       elektronica outer limit funk         14.0
# 5296158                   high difinition ultra tech-house          4.0
# 5296160                                             techno      10679.0
# 5296161                                            electro      14041.0
# 5296162                                              synth       2938.0
# 5296163                                         atmosphere       1016.0
# 5296164                                                low        664.0
# 5296165                                              intel        353.0
# 5296166                          late night summer driving        598.0
# 5296167                                       drum-machine         10.0
# 5296168                                              chirp          3.0
# 5296169                                       mind-melting        890.0
# 5296170                                           chillout      27276.0
# 5296171                                            ambient      17982.0
# 5296172                                           relaxing       9751.0
# 5296173                                          beautiful      29421.0
# 5296174                                              space       1206.0
# 5296175                                          cinematic       1154.0
# 5296176                                        atmospheric       7799.0
# 5296177                                               deep       1920.0
# 5296178                                            surreal        310.0
# 5296179                                       true ambient        109.0
# 5296182              elektroid sounds from the near future         48.0
#
#                                                      genre
# 13                                            great covers
# 14                                        for my dancy mix
# 15                                             stereo cool
# 16                                     dream for me please
# 17       thissongmakesmewanttocrynotafraidtosharemyemot...
# 18                                                   happy
# 19                                                       -
# 20                                        the office girls
# 23                                             future funk
# 24                                                     808
# 25                                       electglitchdubhop
# 26                                         minimal electro
# 27                                       electlgitchdubhop
# 28                                              electronic
# 29                                                 electro
# 30                                             electrofunk
# 31                                                 machine
# 34                                                 electro
# 35                                   mac progressive house
# 38                         orange label ambient electronic
# 41                                                   house
# 42                                                  techno
# 43                                                   dutch
# 44                                                  delsin
# 46                                             black metal
# 47                                        industrial metal
# 48                                extreme industrial metal
# 49                                  industrial black metal
# 50                                             black metal
# 51                                                 finnish
# ...                                                    ...
# 5296147                                            electro
# 5296148                                               warm
# 5296150                                            ambient
# 5296151                                                dub
# 5296152                                         electronic
# 5296153                                        electronica
# 5296154                                          downtempo
# 5296156                       elektronica outer limit funk
# 5296158                   high difinition ultra tech-house
# 5296160                                             techno
# 5296161                                            electro
# 5296162                                              synth
# 5296163                                         atmosphere
# 5296164                                                low
# 5296165                                              intel
# 5296166                          late night summer driving
# 5296167                                       drum-machine
# 5296168                                              chirp
# 5296169                                       mind-melting
# 5296170                                           chillout
# 5296171                                            ambient
# 5296172                                           relaxing
# 5296173                                          beautiful
# 5296174                                              space
# 5296175                                          cinematic
# 5296176                                        atmospheric
# 5296177                                               deep
# 5296178                                            surreal
# 5296179                                       true ambient
# 5296182              elektroid sounds from the near future
#
# [5156960 rows x 14 columns]

# %% [markdown]
# # We just have to find a way to impute these vals now!

# %% [markdown]
# alternative rock -->aleternative
# hip-hop ---> hiphop
# hip hop----> hiphop
# hiphop
# folk
# pop
# rock
# indie
# indie rock ---> indie
# metal
# heavy metal ---> metal
# jazz
# classic rock
# elctronic
# electrocica ---> elctronic
# house ---> electronic
# techno ---> electronic
# trance ---> electronic
# electro --->electronic
# soul
# rap
# country
# blues
# punk
# o/w ---> drop

# %%
#first, sanity check
print(len(df_songs_merge))
# Out:
# 5134665

# %%
def merge_genre(s):
    name_mapping = {
        'alternative rock': 'rock',
        'hip-hop': 'hiphop',
        'hip hop': 'hiphop',
        'indie rock': 'indie',
        'heavy metal': 'metal',
        'electrocica': 'elctronic',
        'house':'electronic',
        'techno': 'electronic',
        'trance': 'electronic',
        'electro': 'electronic'}
    
    keep_set = {
        'hiphop',
        'folk',
        'pop',
        'rock',
        'indie',
        'metal',
        'metal',
        'jazz',
        'classic rock',
        'electronic',
        'soul',
        'rap',
        'country',
        'blues',
        'punk'
    }
    if s in keep_set:
        return s
    elif s in name_mapping:
        return name_mapping[s]
    else:
        return None

df_songs_merge['genre_merged'] = df_songs_merge['genre'].map(merge_genre)
print(len(df_songs_merge))
tmp = df_songs_merge.dropna()
print(len(tmp))
# Out:
# 5134665
# 381087

# %%
#number of songs in each genre
tmp1 = tmp.groupby('genre_merged').count()
print(tmp1)
# Out:
#               track_id  song_name  song_id  album_name  artist_id  \
# genre_merged
# blues             8946       8946     8946        8946       8946
# classic rock     10839      10839    10839       10839      10839
# country           8021       8021     8021        8021       8021
# electronic       55227      55227    55227       55227      55227
# folk             15100      15100    15100       15100      15100
# hiphop           20936      20936    20936       20936      20936
# indie            54052      54052    54052       54052      54052
# jazz             16558      16558    16558       16558      16558
# metal            29365      29365    29365       29365      29365
# pop              40943      40943    40943       40943      40943
# punk             14747      14747    14747       14747      14747
# rap               7086       7086     7086        7086       7086
# rock             87236      87236    87236       87236      87236
# soul             12031      12031    12031       12031      12031
#
#               artist_name  duration  artist_familiarity   year    s/a  \
# genre_merged
# blues                8946      8946                8946   8946   8946
# classic rock        10839     10839               10839  10839  10839
# country              8021      8021                8021   8021   8021
# electronic          55227     55227               55227  55227  55227
# folk                15100     15100               15100  15100  15100
# hiphop              20936     20936               20936  20936  20936
# indie               54052     54052               54052  54052  54052
# jazz                16558     16558               16558  16558  16558
# metal               29365     29365               29365  29365  29365
# pop                 40943     40943               40943  40943  40943
# punk                14747     14747               14747  14747  14747
# rap                  7086      7086                7086   7086   7086
# rock                87236     87236               87236  87236  87236
# soul                12031     12031               12031  12031  12031
#
#               song_name_cleaned  s_cleaned/a    tid    tag  genre_count  genre
# genre_merged
# blues                      8946         8946   8946   8946         8946   8946
# classic rock              10839        10839  10839  10839        10839  10839
# country                    8021         8021   8021   8021         8021   8021
# electronic                55227        55227  55227  55227        55227  55227
# folk                      15100        15100  15100  15100        15100  15100
# hiphop                    20936        20936  20936  20936        20936  20936
# indie                     54052        54052  54052  54052        54052  54052
# jazz                      16558        16558  16558  16558        16558  16558
# metal                     29365        29365  29365  29365        29365  29365
# pop                       40943        40943  40943  40943        40943  40943
# punk                      14747        14747  14747  14747        14747  14747
# rap                        7086         7086   7086   7086         7086   7086
# rock                      87236        87236  87236  87236        87236  87236
# soul                      12031        12031  12031  12031        12031  12031
